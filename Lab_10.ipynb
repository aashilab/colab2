# %% [markdown]
# <a href="https://colab.research.google.com/github/aashilab/colab2/blob/main/Lab_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Warshall algorithm to find reachability between all pairs of vertices in a graph.
# Problem Description:
# Understand transitive closure of a graph. Use Python to compute reachability using matrix method.

# %% [markdown]
# #Theory
# Warshall algorithm finds whether a path exists between every pair of vertices. It updates the adjacency matrix step by step. If there is a path from i to j through k, then the entry becomes 1.
#
# ## Algorithm
# 1. Represent graph using adjacency matrix.
# 2. For each intermediate vertex k
# 3. Check all pairs i and j
# 4. Update value if path exists through k
# 4. Repeat for all vertices

# %%
def warshall_algorithm():
    n = 5
    print(f"Enter the adjacency matrix for {n} vertices (row by row, space-separated):")
    print("Example row: 1 0 1 0 0")

    matrix = []
    for i in range(n):
        row = list(map(int, input(f"Row {i+1}: ").split()))
        matrix.append(row)

    for k in range(n):
        for i in range(n):
            for j in range(n):
                matrix[i][j] = matrix[i][j] or (matrix[i][k] and matrix[k][j])

    print("\n--- Transitive Closure (Path Existence) ---")
    for i in range(n):
        for j in range(n):
            status = "Exists" if matrix[i][j] == 1 else "None"
            print(f"Path {i+1}->{j+1}: {status.ljust(6)}", end="  ")
        print()

if __name__ == "__main__":
    warshall_algorithm()
# Out:
# Enter the adjacency matrix for 5 vertices (row by row, space-separated):
# Example row: 1 0 1 0 0
# Row 1: 1 0 1 0 0
# Row 2: 1 1 0 0 0
# Row 3: 1 0 0 0 0
# Row 4: 0 0 0 0 0
# Row 5: 1 0 1 0 0
#
# --- Transitive Closure (Path Existence) ---
# Path 1->1: Exists  Path 1->2: None    Path 1->3: Exists  Path 1->4: None    Path 1->5: None
# Path 2->1: Exists  Path 2->2: Exists  Path 2->3: Exists  Path 2->4: None    Path 2->5: None
# Path 3->1: Exists  Path 3->2: None    Path 3->3: Exists  Path 3->4: None    Path 3->5: None
# Path 4->1: None    Path 4->2: None    Path 4->3: None    Path 4->4: None    Path 4->5: None
# Path 5->1: Exists  Path 5->2: None    Path 5->3: Exists  Path 5->4: None    Path 5->5: None

# %% [markdown]
# Now, let's implement
# 1. Modify program to take matrix input from user
# 2. Apply algorithm on graph with 5 vertices
# 3. Compare Warshall with Floyd algorithm
# 4. Display path existence in readable format

# %% [markdown]
# ## Find shortest paths between all pairs of vertices using Floyd Warshall algorithm.

# %% [markdown]
# #Understand all pairs shortest path problem. Implement dynamic programming approach in Python.
#
# * Given a weighted graph with positive or negative edge weights, find
# shortest distances between every pair of vertices.

# %% [markdown]
# # Theory
# Floyd Warshall algorithm computes shortest paths between all pairs of nodes. It updates the distance matrix by checking if a shorter path exists through an intermediate vertex. Works with negative weights but fails with negative cycles.
#
# Algorithm
# 1. Represent graph using distance matrix.
# 2. Initialize matrix with given weights.
# 3. Set distance of node to itself as 0.
# 4. For each intermediate vertex k
# 5. Update distance[i][j] = min(distance[i][j], distance[i][k] + distance[k][j])
# 6. Repeat for all vertices

# %%
def floyd_warshall_complete():
    n = 5
    print("Enter the 5x5 distance matrix (use 'inf' for no edge):")
    dist = []
    parent = [[None for _ in range(n)] for _ in range(n)]

    for i in range(n):
        row = list(map(lambda x: float('inf') if x == 'inf' else int(x), input(f"Row {i+1}: ").split()))
        dist.append(row)
        for j in range(n):
            if dist[i][j] != float('inf') and i != j:
                parent[i][j] = i
    for k in range(n):
        for i in range(n):
            for j in range(n):
                if dist[i][k] + dist[k][j] < dist[i][j]:
                    dist[i][j] = dist[i][k] + dist[k][j]
                    parent[i][j] = parent[k][j]
    for i in range(n):
        if dist[i][i] < 0:
            print("Negative Cycle Detected at Vertex", i+1)
            return
    print("\n--- Shortest Path Retrieval ---")
    start = int(input("Enter starting vertex (1-5): ")) - 1
    end = int(input("Enter ending vertex (1-5): ")) - 1

    if dist[start][end] == float('inf'):
        print(f"No path exists between {start+1} and {end+1}")
    else:
        path = []
        curr = end
        while curr is not None:
            path.append(curr + 1)
            if curr == start: break
            curr = parent[start][curr]

        path.reverse()
        print(f"Shortest Distance: {dist[start][end]}")
        print(f"Path: {' -> '.join(map(str, path))}")

if __name__ == "__main__":
    floyd_warshall_complete()
# Out:
# Enter the 5x5 distance matrix (use 'inf' for no edge):
# Row 1: 0 5 inf 10 inf
# Row 2: 3 0 -1 inf 5
# Row 3: inf inf 0 2 inf
# Row 4: inf 1 inf 0 -2
# Row 5: 4 inf inf inf 0
#
# --- Shortest Path Retrieval ---
# Enter starting vertex (1-5): 1
# Enter ending vertex (1-5): 5
# Shortest Distance: 4
# Path: 1 -> 2 -> 3 -> 4 -> 5

# %% [markdown]
# # Excercise
# 1. Take matrix input from user
# 2. Detect negative cycle in graph
# 3. Print shortest path between two given vertices
# 4. Compare with Dijkstra algorithm
