# %% [markdown]
# <a href="https://colab.research.google.com/github/aashilab/colab2/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {}
    predecessors = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')
        predecessors[node] = None

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None: break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    return distances, predecessors

def get_path(predecessors, target):
    path = []
    curr = target
    while curr is not None:
        path.append(curr)
        curr = predecessors[curr]
    return " -> ".join(reversed(path))

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3},
          'E': {'C': 8, 'F': 1},
    'F': {'D': 2, 'E': 1}
}
test_sources = [ 'D']

for source in test_sources:
    print(f"\n--- Results for Source Node: {source} ---")
    distances, predecessors = dijkstra(graph, source)


    for target in sorted(graph.keys()):
        path_str = get_path(predecessors, target)
        print(f"To {target}: Total Distance = {distances[target]}, Path = [{path_str}]")
# Out:
# --- Results for Source Node: D ---
# To A: Total Distance = 5, Path = [D -> C -> A]
# To B: Total Distance = 8, Path = [D -> C -> B]
# To C: Total Distance = 3, Path = [D -> C]
# To D: Total Distance = 0, Path = [D]
# To E: Total Distance = inf, Path = [E]
# To F: Total Distance = inf, Path = [F]

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
